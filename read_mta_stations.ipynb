# %%
import numpy as np
import pandas as pd

# %%
def read_mta_stations():
    ''' Read the MTA master list into a pd.DataFrame (Put the CSV file on the repository!!)
    data source = https://data.cityofnewyork.us/Transportation/Subway-Stations/arq3-7z49 (export data as csv)
    '''
    df = pd.read_csv("mta_stations.csv")
    df.rename(columns = {"OBJECTID": "key", "NAME":"name", "the_geom":"location"}, inplace = True)
    
    df["lon"] = df.location.str.split().str.get(1).str.strip('(')
    df["lat"] = df.location.str.split().str.get(2).str.strip(')')
    df = df[["key","name","LINE","lon","lat"]]
    df = df.sort_values(["name","LINE"], ascending = [True, True])
    
    return df
    
    '''
    return pd.DataFrame (columns = [station (unique), lattitude, longitude])
    '''

# %%
stations = read_mta_stations()

# %%
stations
# Out:
#      key                              name             LINE  \
# 158  159                          103rd St                1
# 457  458                          103rd St    4-6-6 Express
# 160  161                          103rd St            A-B-C
# 188  189           103rd St - Corona Plaza                7
# 97    98                          104th St              A-S
# 13    14                   104th-102nd Sts              J-Z
# 449  450                          110th St    4-6-6 Express
# 189  190                          111th St                7
# 82    83                          111th St              A-S
# 208  209                          111th St                J
# 169  170                          116th St              2-3
# 461  462                          116th St    4-6-6 Express
# 397  398                          116th St            A-B-C
# 166  167    116th St - Columbia University                1
# 209  210                          121st St              J-Z
# 286  287                          125th St                1
# 167  168                          125th St              2-3
# 467  468                          125th St  4-5-6-6 Express
# 398  399                          125th St          A-B-C-D
# 168  169                          135th St              2-3
# 439  440                          135th St            A-B-C
# 171  172           137th St - City College                1
# 140  141        138th St - Grand Concourse              4-5
# 155  156                          145th St                1
# 172  173                          145th St                3
# 294  295                          145th St          A-B-C-D
# 288  289        149th St - Grand Concourse              2-5
# 46    47        149th St - Grand Concourse                4
# 438  439                           14th St            1-2-3
# 443  444                           14th St            A-C-E
# ..   ...                               ...              ...
# 170  171                       Tremont Ave              B-D
# 104  105                Union Sq - 14th St  4-5-6-6 Express
# 383  384                Union Sq - 14th St                L
# 378  379                Union Sq - 14th St          N-Q-R-W
# 35    36                          Union St            D-N-R
# 297  298                         Utica Ave              A-C
# 270  271     Van Cortlandt Park - 242nd St                1
# 45    46                    Van Siclen Ave              3-4
# 213  214                    Van Siclen Ave              A-C
# 11    12                    Van Siclen Ave              J-Z
# 100  101         Vernon Blvd - Jackson Ave      7-7 Express
# 83    84  W 4th St - Washington Sq (Lower)          B-D-F-M
# 205  206  W 4th St - Washington Sq (Upper)            A-C-E
# 197  198            W 8th St - NY Aquarium              F-Q
# 279  280              Wakefield - 241st St                2
# 429  430                           Wall St              2-3
# 419  420                           Wall St              4-5
# 271  272      West Farms Sq - E Tremont Av              2-5
# 201  202    Westchester Sq - E Tremont Ave      6-6 Express
# 420  421                      Whitehall St              R-W
# 51    52                      Whitlock Ave                6
# 73    74                        Wilson Ave                L
# 44    45                       Winthrop St              2-5
